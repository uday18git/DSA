# %%
# 1A 
# Faltu

# %%
# 1B

words = ["hi","hello","mic","testing"]
tuples =  [(s,len(s))for s in words]
sorted_tuples = sorted(tuples,key=lambda x:x[1])
print(sorted_tuples)
# Out:
# [('hi', 2), ('mic', 3), ('hello', 5), ('testing', 7)]

# %%
# 2A
import math
a=int(input("enter first number"))
b=int(input("enter second number"))
flag=True
for i in range(a,b):
    flag=True
    for j in range(2,math.floor(math.sqrt(i))+1):
        if i%j==0:
            flag=False
            break
    if(flag ==True and i>1):
        print(i)
# Out:
# enter first number1
# enter second number10
# 2
# 3
# 5
# 7

# %%
# 2B
subjects = ['Data Structures and Algorithms', 'Computer Organization and Architecture', 'Database Management Systems', 'Operating Systems', 'Python Programming Lab', 'Web Technologies and Applications']
subjects.append("hey")
subjects.insert(2,"Hello")
subjects.remove("hey")
# print(subjects.pop())
# print(subjects.pop(2))

print(subjects)
# Out:
# Web Technologies and Applications
# Hello
# ['Data Structures and Algorithms', 'Computer Organization and Architecture', 'Database Management Systems', 'Operating Systems', 'Python Programming Lab']

# %%
#3A
dictionary = {}

# Define a function to add a new entry to the dictionary
def add_entry():
    word = input("Enter the word to add: ")
    meaning = input("Enter the meaning of the word: ")
    dictionary[word] = meaning
    print("Entry added successfully")

# Define a function to search for a word and retrieve its meaning
def search_word():
    word = input("Enter the word to search: ")
    if word in dictionary:
        print("The meaning of", word, "is", dictionary[word])
    else:
        print("Word not found in dictionary")

# Define a function to find words with the same meaning
def find_words():
    meaning = input("Enter the meaning to search: ")
    words = [word for word, mean in dictionary.items() if mean == meaning]
    if words:
        print("Words with the same meaning:", ", ".join(words))
    else:
        print("No words found with the given meaning")

# Define a function to remove an entry from the dictionary
def remove_entry():
    word = input("Enter the word to remove: ")
    if word in dictionary:
        del dictionary[word]
        print("Entry removed successfully")
    else:
        print("Word not found in dictionary")

# Define a function to display all words sorted alphabetically
def display_words():
    words = sorted(dictionary.keys())
    if words:
        print("List of words in the dictionary:")
        for word in words:
            print(word)
    else:
        print("Dictionary is empty")

# Define a function to display the menu of operations
def display_menu():
    print("Dictionary Operations:")
    print("1. Add an entry")
    print("2. Search for a word")
    print("3. Find words with the same meaning")
    print("4. Remove an entry")
    print("5. Display all words sorted alphabetically")
    print("6. Quit")

while True:
    display_menu()
    choice = input("Enter your choice (1-6): ")
    if choice == "1":
        add_entry()
    elif choice == "2":
        search_word()
    elif choice == "3":
        find_words()
    elif choice == "4":
        remove_entry()
    elif choice == "5":
        display_words()
    elif choice == "6":
        print("Exiting dictionary")
        break
    else:
        print("Invalid choice, please try again")

# %%
# 3B
array=[10,34,5,2,124,214,13,3,1]
maxi=-1e9
for i in array:
    if i>maxi:
        maxi=i
print(maxi)
mini=1e9
for i in array:
    if i<mini:
        mini=i
print(mini)
sec_max=-1e9
for i in array:
    if i>sec_max and i<maxi:
        sec_max=i
print(sec_max)
# Out:
# 214
# 1
# 124

# %%
# 4a

passwd = {'rahul': 'genius', 'kumar': 'smart', 'ankita': 'intelligent'}

# Print all the items in the dictionary
print("Dictionary items:")
for item in passwd.items():
    print(item)

# Print all the keys in the dictionary
print("Dictionary keys:")
for key in passwd.keys():
    print(key)

# Print all the values in the dictionary
print("Dictionary values:")
for value in passwd.values():
    print(value)

# Get the password of a user
user = input("Enter the username to get password: ")
if user in passwd:
    print("Password of", user, "is", passwd[user])
else:
    print("User not found in dictionary")

# Change the password of a user
user = input("Enter the username to change password: ")
if user in passwd:
    new_passwd = input("Enter the new password: ")
    passwd[user] = new_passwd
    print("Password of", user, "changed successfully")
else:
    print("User not found in dictionary")
# Out:
# Dictionary items:
# ('rahul', 'genius')
# ('kumar', 'smart')
# ('ankita', 'intelligent')
# Dictionary keys:
# rahul
# kumar
# ankita
# Dictionary values:
# genius
# smart
# intelligent
# Enter the username to get password: rahul
# Password of rahul is genius
# Enter the username to change password: rahul
# Enter the new password: hey
# Password of rahul changed successfully

# %%
passwd.items() # returns list of tuples of key value pairs
# Out:
# dict_items([('rahul', 'hey'), ('kumar', 'smart'), ('ankita', 'intelligent')])

# %%
# 4b

import re
text= "aa1234aa"
vowels = re.compile('[aeiouAEIOU]')
vowels_count=len(re.findall(vowels,text))
digits = re.compile(r"\d")
digit_count = len(re.findall(digits,text))
print(digit_count)
consonant = re.compile('[bcdfghjklmnpqrstvwxyzBCDFGHJKLMNPQRSTVWXYZ]')
consonant_count = len(re.findall(consonant,text))
print(consonant_count)
print(vowels_count)
# Out:
# 4
# 0
# 4

# %%
# 5a

my_tuple = (1, 2, 3, 4, 5)
#adding items
tup = (6,)
my_tuple+=tup
print(len(my_tuple))
print( 1 in my_tuple)
print(my_tuple[3])
print(my_tuple)
# Out:
# 6
# True
# 4
# (1, 2, 3, 4, 5, 6)

# %%
# 5 b 


with open("sample.txt",'w') as file:
    for i in range(5):
        x=input("Enter a line: ")
        file.write(x+'\n')
        
with open("sample.txt",'r') as file:
    content = file.read()
    text=content.split()
    max_len = max(text,key=len)
    
    min_len = min(text,key=len)
    print("word with max length", max_len)
    print(min_len)
# Out:
# Enter a line: sdpadap
# Enter a line: adoskpadaopd
# Enter a line: aoksdpoakdpoaksd
# Enter a line: osakdpadkpaoskdpaodsa
# Enter a line: aposkdapodkapodkapodkapod hiiiiiiiiiiii
# aposkdapodkapodkapodkapod
# sdpadap

# %%
# 6a

def binary_search(arr,low,high,key):
    if low<=high:
        mid = (low+high)//2
        if arr[mid]==key:
            return mid
        elif arr[mid]>key:
            return binary_search(arr,low,mid-1,key)
        else:
            return binary_search(arr,mid+1,high,key)
            
    return -1
            
arr = [10,12,9,1,13,4124,512,342]
print(binary_search(arr,0,len(arr)-1,1))
# Out:
# 3

# %%
# 6b.	Write a python program to simulate saving account processing in a bank using constructors. 
# Create Deposit and Withdraw with other member function and Check for Validation while withdrawing the amount. 
# Raise the appropriate exceptions when depositing and withdrawing an incorrect amount.
# Display appropriate messages.
class SavingsAccount:
    def __init__(self, initial_balance=0):
        if initial_balance < 0:
            raise ValueError("Initial balance cannot be negative.")
        self.balance = initial_balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount should be greater than zero.")
        self.balance += amount
        print(f"Amount {amount} deposited successfully.")
        self.display_balance()

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Withdrawal amount should be greater than zero.")
        if amount > self.balance:
            raise ValueError("Insufficient balance.")
        self.balance -= amount
        print(f"Amount {amount} withdrawn successfully.")
        self.display_balance()

    def display_balance(self):
        print(f"Current balance: {self.balance}")


# Example usage
try:
    account = SavingsAccount(1000)
    account.display_balance()
    account.deposit(500)
    account.withdraw(200)
    account.withdraw(2000)  # Raises ValueError: Insufficient balance
    account.withdraw(-100)  # Raises ValueError: Withdrawal amount should be greater than zero
except ValueError as error:
    print(f"Error: {str(error)}")

# %%
# 7 A
class Stack:
    def __init__(self):
        self.stack = []

    def is_empty(self):
        return len(self.stack) == 0

    def push(self, item):
        self.stack.append(item)
        print(f"Pushed {item} into the stack.")

    def pop(self):
        if self.is_empty():
            raise IndexError("Stack is empty. Cannot pop an item.")
        return self.stack.pop()

    def display(self):
        if self.is_empty():
            print("Stack is empty.")
        else:
            print("Stack content:")
            for item in reversed(self.stack):
                print(item)


class Queue:
    def __init__(self):
        self.queue = []

    def is_empty(self):
        return len(self.queue) == 0

    def enqueue(self, item):
        self.queue.append(item)
        print(f"Enqueued {item} into the queue.")

    def dequeue(self):
        if self.is_empty():
            raise IndexError("Queue is empty. Cannot dequeue an item.")
        return self.queue.pop(0)

    def display(self):
        if self.is_empty():
            print("Queue is empty.")
        else:
            print("Queue content:")
            for item in self.queue:
                print(item)


# Example usage
try:
    # Stack operations
    stack = Stack()
    stack.push(10)
    stack.push(20)
    stack.push(30)
    stack.display()
    print("Popped item:", stack.pop())
    stack.display()
    print("Popped item:", stack.pop())
    stack.display()
    # stack.pop()  # Raises IndexError: Stack is empty. Cannot pop an item.

    # Queue operations
    queue = Queue()
    queue.enqueue("A")
    queue.enqueue("B")
    queue.enqueue("C")
    queue.display()
    print("Dequeued item:", queue.dequeue())
    queue.display()
    print("Dequeued item:", queue.dequeue())
    queue.display()
    # queue.dequeue()  # Raises IndexError: Queue is empty. Cannot dequeue an item.

except IndexError as error:
    print(f"Error: {str(error)}")
# Out:
# Pushed 10 into the stack.
# Pushed 20 into the stack.
# Pushed 30 into the stack.
# Stack content:
# 30
# 20
# 10
# Popped item: 30
# Stack content:
# 20
# 10
# Popped item: 20
# Stack content:
# 10
# Enqueued A into the queue.
# Enqueued B into the queue.
# Enqueued C into the queue.
# Queue content:
# A
# B
# C
# Dequeued item: A
# Queue content:
# B
# C
# Dequeued item: B
# Queue content:
# C

# %%
import numpy as np

def main():
    # Read and display a 2D Array
    rows = int(input("Enter the number of rows: "))
    cols = int(input("Enter the number of columns: "))
    
    # Initialize the 2D array
    arr = np.zeros((rows, cols), dtype=int)
    
    for i in range(rows):
        for j in range(cols):
            arr[i][j] = int(input(f"Enter element at position ({i}, {j}): "))
    
    print("2D Array:")
    print(arr)
    
    # Display the array elements in reverse order
    print("Array elements in reverse order:")
    reversed_arr = np.flip(arr)
    print(reversed_arr)
    
    # Display principal diagonal elements
    print("Principal diagonal elements:")
    diagonal_elements = np.diagonal(arr)
    print(diagonal_elements)
    
    # Sort the 2D array in ascending and descending order
    sorted_asc = np.sort(arr, axis=None)
    sorted_desc = np.sort(arr, axis=None)[::-1]
    sorted_asc = sorted_asc.reshape(arr.shape)
    sorted_desc = sorted_desc.reshape(arr.shape)
    print("Sorted array in ascending order:")
    print(sorted_asc)
    
    print("Sorted array in descending order:")
    print(sorted_desc)

if __name__ == "__main__":
    main()
# Out:
# Enter the number of rows: 2
# Enter the number of columns: 2
# Enter element at position (0, 0): 10
# Enter element at position (0, 1): 9
# Enter element at position (1, 0): 11
# Enter element at position (1, 1): 0
# 2D Array:
# [[10  9]
#  [11  0]]
# Array elements in reverse order:
# [[ 0 11]
#  [ 9 10]]
# Principal diagonal elements:
# [10  0]
# Sorted array in ascending order:
# [[ 0  9]
#  [10 11]]
# Sorted array in descending order:
# [[11 10]
#  [ 9  0]]

# %%
# 8a
import random

numbers = []
for _ in range(20):
    numbers.append(random.randint(1, 10000))

print("Random Numbers:", numbers)

odd_numbers = []
for num in numbers:
    if num % 2 != 0:
        num_length = len(str(num))
        if num_length == 2 or num_length == 4:
            odd_numbers.append(num)

print("Odd numbers of length 2 and 4:")
for odd_num in odd_numbers:
    print(odd_num)
# Out:
# Random Numbers: [4758, 8690, 9087, 9609, 3424, 7318, 3574, 2768, 5950, 3782, 4683, 3228, 1539, 1676, 5772, 189, 1523, 1428, 975, 5019]
# Odd numbers of length 2 and 4:
# 9087
# 9609
# 4683
# 1539
# 1523
# 5019

# %%
#8 b
def count_characters(text):
    uppercase_count = 0
    lowercase_count = 0
    digit_count = 0

    for char in text:
        if char.isupper():
            uppercase_count += 1
        elif char.islower():
            lowercase_count += 1
        elif char.isdigit():
            digit_count += 1

    return uppercase_count, lowercase_count, digit_count

def display_file_details(filepath):
    with open(filepath, 'r') as file:
        file_content = file.read()

    uppercase_count, lowercase_count, digit_count = count_characters(file_content)

    print(f"File Details - {filepath}:")
    print("---------")
    print("Content:")
    print(file_content)
    print("---------")
    print("Character Counts:")
    print(f"Uppercase: {uppercase_count}")
    print(f"Lowercase: {lowercase_count}")
    print(f"Digits: {digit_count}")


def create_text_file(filepath):
    with open(filepath, 'w') as file:
        print("Enter 5-6 lines of text:")
        for _ in range(5):
            line = input()
            file.write(line+'\n')

    print(f"Text file created successfully at {filepath}")


# Example usage
file_path = "sample.txt"
create_text_file(file_path)
display_file_details(file_path)
# Out:
# Enter 5-6 lines of text:
# asdija
# asdadsa
# dasdadsada
# dasdasdaddasd
# dvndiovqisdqd
# Text file created successfully at sample.txt
# File Details - sample.txt:
# ---------
# Content:
# asdija
# asdadsa
# dasdadsada
# dasdasdaddasd
# dvndiovqisdqd
#
# ---------
# Character Counts:
# Uppercase: 0
# Lowercase: 49
# Digits: 0

# %%
# 9a
import matplotlib.pyplot as plt
import pandas as pd
df1=pd.read_csv('iris.csv')



df1.plot()
plt.ylim(0,10)
plt.show()





plt.scatter(df1.index, df1['sepal.length'])
plt.title("Scatter Plot of Column 'col1'")
plt.xlabel("Index")
plt.ylabel("Column 'sepal.length'")
plt.show()




plt.scatter(df1.index, df1['sepal.length'], c=df1['petal.length'],cmap='viridis')
plt.title("Scatter Plot with Different Colors")
plt.xlabel("Index")
plt.ylabel("Column 'sepal.length'")
plt.colorbar(label="Column petal.length'")
plt.show()






plt.hist(df1['variety'], bins=10)
plt.title("Histogram of Column 'variety'")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('iris.csv')
df.plot()
plt.ylim(0,10)
plt.show()

plt.scatter(df.index,df['sepal.length'])
plt.title("index vs sepal length")
plt.xlabel("index")
plt.ylabel("sepal length")
plt.show()

plt.scatter(df.index,df['sepal.length'],c=df['petal.length'],cmap='viridis')
plt.title("index vs sepal length")
plt.xlabel("index")
plt.ylabel("sepal length")
plt.colorbar(label="petal length")
plt.show()

plt.hist(df['variety'],bins=100)
plt.title("histogram")
plt.show()

# %%
#9b
def divide_numbers(a,b):
    try:
        a/b
    except ZeroDivisionError:
        print("Error cannot divide by zero")
    except TypeError:
        print("Wrong datatype")
    else:
        print("result of the divison: ",a/b)
    finally:
        print("Division operation successful")
divide_numbers(10,2)
divide_numbers(10,0)
divide_numbers(10,'a')
# Out:
# result of the divison:  5.0
# Division operation successful
# Error cannot divide by zero
# Division operation successful
# Wrong datatype
# Division operation successful

# %%
#10 a 
try:
    print(o)
except(NameError):
    print("Name Error Found")
try:
    a=[1,2,3,4]
    print(a[4])
except(IndexError):
    print("Index Error Found")
try:
    a={1:2,2:4}
    print(a[3])
except(KeyError):
    print("Key Error Found")
try:
    a=1
    print(a/0)
except(ZeroDivisionError):
    print("Zero Division Error Found")
# Out:
# Name Error Found
# Index Error Found
# Key Error Found
# Zero Division Error Found

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv('iris.csv')
print("\nTop 5\n")
print(data.head(5))
print("\nBottom 5\n")
print(data.tail(5))
print("\nInformation\n")
print(data.info())
print("\nDescription\n")
print(df.describe())
df.plot()
plt.title("Visualization of the Dataset")
plt.ylim(0,10)
plt.show()
# Out:
# Top 5
#
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#
# Bottom 5
#
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# Information
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# Description
#
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv("iris.csv")
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
df.plot()
plt.ylim(0,10)
plt.show()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
